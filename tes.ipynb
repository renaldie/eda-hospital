# %%
import os

for folder in os.listdir("./assets/output"):
    for file in os.listdir(f"./assets/output/{folder}"):
        if file.endswith(".json"):
            os.remove(f"./assets/output/{folder}/{file}")
